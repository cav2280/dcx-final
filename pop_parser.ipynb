# %%
import pandas as pd

# %%
#파일 전처리
df = pd.read_csv(r'Data\연령_및_성별_인구_–_읍면동_연도_끝자리_0_5___시군구_그_외_연도__20230713151501.csv',names=['행정구역별(읍면동)','연령별','총인구(명)'],encoding='cp949')

province_status=0
counter=0
for province in df['행정구역별(읍면동)']:
    status=1
    if province == '서울특별시':
        province_status = 1
        status=0
    elif province == '부산광역시':
        province_status = 2
        status=0
    elif province == '대구광역시':
        province_status = 3
        status=0
    elif province == '인천광역시':
        province_status = 4
        status=0
    elif province == '광주광역시':
        province_status = 5
        status=0
    elif province == '대전광역시':
        province_status = 6
        status=0
    elif province == '울산광역시':
        province_status = 7
        status=0
    elif province == '세종특별자치시':
        province_status = 8
        status=0
    elif province == '경기도':
        province_status = 9
        status=0
    elif province == '강원도':
        province_status = 10
        status=0
    elif province == '충청북도':
        province_status = 11
        status=0
    elif province == '충청남도':
        province_status = 12
        status=0
    elif province == '전라북도':
        province_status = 13
        status=0
    elif province == '전라남도':
        province_status = 14
        status=0
    elif province == '경상북도':
        province_status = 15
        status=0
    elif province == '경상남도':
        province_status = 16
        status=0
    elif province == '제주도':
        province_status = 17
        status=0
    elif province == '경북도':
        province_status = 18
        status=0
    elif province == '경남도':
        province_status = 19
        status=0
    elif province == '제주특별자치도':
        province_status = 20
        status=0

    if province_status == 1 and  status == 1:   
        df['행정구역별(읍면동)'][counter]='서울특별시 '+province
    elif province_status == 2 and  status == 1:
        df['행정구역별(읍면동)'][counter]='부산광역시 '+province
    elif province_status == 3 and  status == 1:
        df['행정구역별(읍면동)'][counter]='대구광역시 '+province
    elif province_status == 4 and  status == 1:
        df['행정구역별(읍면동)'][counter]='인천광역시 '+province
    elif province_status == 5 and  status == 1:
        df['행정구역별(읍면동)'][counter]='광주광역시 '+province
    elif province_status == 6 and  status == 1:
        df['행정구역별(읍면동)'][counter]='대전광역시 '+province
    elif province_status == 7 and  status == 1:
        df['행정구역별(읍면동)'][counter]='울산광역시 '+province
    elif province_status == 8 and  status == 1:
        df['행정구역별(읍면동)'][counter]='세종특별자치시 '+province
    elif province_status == 9 and  status == 1:
        df['행정구역별(읍면동)'][counter]='경기도 '+province
    elif province_status == 10 and  status == 1:
        df['행정구역별(읍면동)'][counter]='강원도 '+province
    elif province_status == 11 and  status == 1:
        df['행정구역별(읍면동)'][counter]='충청북도 '+province
    elif province_status == 12 and  status == 1:
        df['행정구역별(읍면동)'][counter]='충청남도 '+province
    elif province_status == 13 and  status == 1:
        df['행정구역별(읍면동)'][counter]='전라북도 '+province
    elif province_status == 14 and  status == 1:
        df['행정구역별(읍면동)'][counter]='전라남도 '+province
    elif province_status == 15 and  status == 1:
        df['행정구역별(읍면동)'][counter]='경상북도 '+province
    elif province_status == 16 and  status == 1:
        df['행정구역별(읍면동)'][counter]='경상남도 '+province
    elif province_status == 17 and  status == 1:
        df['행정구역별(읍면동)'][counter]='제주도 '+province
    elif province_status == 18 and  status == 1:
        df['행정구역별(읍면동)'][counter]='경북도 '+province
    elif province_status == 19 and  status == 1:
        df['행정구역별(읍면동)'][counter]='경남도 '+province
    elif province_status == 20 and  status == 1:
        df['행정구역별(읍면동)'][counter]='제주특별자치도 '+province
    # print(df['행정구역별(읍면동)'][counter])
    counter+=1

# df.set_index('행정구역별(읍면동)',inplace=True)
print(df)
# Out:
#        행정구역별(읍면동)  연령별    총인구(명)
# 0      행정구역별(읍면동)  연령별      2015
# 1      행정구역별(읍면동)  연령별    총인구(명)
# 2              전국   합계  51069375
# 3              읍부   합계   4616802
# 4              면부   합계   4774878
# ..            ...  ...       ...
# 324    제주특별자치도 읍부   합계    129134
# 325    제주특별자치도 면부   합계     31078
# 326    제주특별자치도 동부   합계    445407
# 327   제주특별자치도 제주시   합계    451758
# 328  제주특별자치도 서귀포시   합계    153861
#
# [329 rows x 3 columns]

# %%
def population(location):
    population = int(df.loc[df['행정구역별(읍면동)'] == location, '총인구(명)'])
    print("%d입니다."%population)

locate='서울특별시 강남구'
population(locate)
# Out:
# 541688입니다.
# C:\Users\kpp08\AppData\Local\Temp\ipykernel_27524\1820098997.py:2: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   population = int(df.loc[df['행정구역별(읍면동)'] == location, '총인구(명)'])
