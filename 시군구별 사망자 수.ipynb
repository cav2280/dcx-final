# %%
import pandas as pd
import numpy as np

# %%
try:
    df = pd.read_csv('시군구_성_연령_5세_별_사망자수_1997___사망률_1998__20230714110101.csv', encoding='cp949')
except:
    df = pd.read_csv('시군구_성_연령_5세_별_사망자수_1997___사망률_1998__20230714110101.csv', encoding='cp949')

province_status = 0
counter = 0
for province in df['시군구별']:
    status = 1
    if province == '서울특별시':
        province_status = 1
        status = 0
    elif province == '부산광역시':
        province_status = 2
        status = 0
    elif province == '대구광역시':
        province_status = 3
        status = 0
    elif province == '인천광역시':
        province_status = 4
        status = 0
    elif province == '광주광역시':
        province_status = 5
        status = 0
    elif province == '대전광역시':
        province_status = 6
        status = 0
    elif province == '울산광역시':
        province_status = 7
        status = 0
    elif province == '세종특별자치시':
        province_status = 8
        status = 0
    elif province == '경기도':
        province_status = 9
        status = 0
    elif province == '강원도':
        province_status = 10
        status = 0
    elif province == '충청북도':
        province_status = 11
        status = 0
    elif province == '충청남도':
        province_status = 12
        status = 0
    elif province == '전라북도':
        province_status = 13
        status = 0
    elif province == '전라남도':
        province_status = 14
        status = 0
    elif province == '경상북도':
        province_status = 15
        status = 0
    elif province == '경상남도':
        province_status = 16
        status = 0
    elif province == '제주도':
        province_status = 17
        status = 0
    elif province == '경북도':
        province_status = 18
        status = 0
    elif province == '경남도':
        province_status = 19
        status = 0
    elif province == '제주도':
        province_status = 20
        status = 0

    if province_status == 1 and status == 1:
        df['시군구별'][counter] = '서울특별시 '+province
    elif province_status == 2 and status == 1:
        df['시군구별'][counter] = '부산광역시 '+province
    elif province_status == 3 and status == 1:
        df['시군구별'][counter] = '대구광역시 '+province
    elif province_status == 4 and status == 1:
        df['시군구별'][counter] = '인천광역시 '+province
    elif province_status == 5 and status == 1:
        df['시군구별'][counter] = '광주광역시 '+province
    elif province_status == 6 and status == 1:
        df['시군구별'][counter] = '대전광역시 '+province
    elif province_status == 7 and status == 1:
        df['시군구별'][counter] = '울산광역시 '+province
    elif province_status == 8 and status == 1:
        df['시군구별'][counter] = '세종특별자치시 '+province
    elif province_status == 9 and status == 1:
        df['시군구별'][counter] = '경기도 '+province
    elif province_status == 10 and status == 1:
        df['시군구별'][counter] = '강원도 '+province
    elif province_status == 11 and status == 1:
        df['시군구별'][counter] = '충청북도 '+province
    elif province_status == 12 and status == 1:
        df['시군구별'][counter] = '충청남도 '+province
    elif province_status == 13 and status == 1:
        df['시군구별'][counter] = '전라북도 '+province
    elif province_status == 14 and status == 1:
        df['시군구별'][counter] = '전라남도 '+province
    elif province_status == 15 and status == 1:
        df['시군구별'][counter] = '경상북도 '+province
    elif province_status == 16 and status == 1:
        df['시군구별'][counter] = '경상남도 '+province
    elif province_status == 17 and status == 1:
        df['시군구별'][counter] = '제주특별자치도 '+province
    elif province_status == 18 and status == 1:
        df['시군구별'][counter] = '경북도 '+province
    elif province_status == 19 and status == 1:
        df['시군구별'][counter] = '경남도 '+province
    elif province_status == 20 and status == 1:
        df['시군구별'][counter] = '제주도 '+province
    # print(popDf['행정구역별(읍면동)'][counter])

    if '부' in df['시군구별'][counter][-1:] or '국' in df['시군구별'][counter][-1:] or ')' in df['시군구별'][counter][-1:]:
            # print(popDf['행정구역별(읍면동)'][counter])
            df['시군구별'][counter]=df.drop(counter,inplace=True)
    elif '도' in df['시군구별'][counter] and '서울특별시 도봉구' != df['시군구별'][counter] and '부산광역시 영도구' != df['시군구별'][counter]:
        if '구' in df['시군구별'][counter][-1:]:
            # print(popDf['행정구역별(읍면동)'][counter])
            df['시군구별'][counter]=df.drop(counter,inplace=True)
    if status==0:
        # print(popDf['행정구역별(읍면동)'][counter])
        df['시군구별'][counter]=df.drop(counter,inplace=True)
    counter+=1
    # df = df.reset_index(drop=True)
    # print(counter)
# 두 번째 행 삭제
df = df.drop([0])
df = df.drop(['성별', '연령(5세)별','2015.1'], axis=1)   
df = df.reset_index(drop=True)
df.rename(columns={'시군구별': '지역', '2015': '사망자 수'}, inplace=True)
df = df.replace('-', np.nan)
df = df.dropna()
df.loc[df['지역'] == '경상남도 통합창원시', '지역'] = '경상남도 창원시'
df
# Out:
#                지역 사망자 수
# 0       서울특별시 종로구   829
# 1        서울특별시 중구   689
# 2       서울특별시 용산구  1113
# 3       서울특별시 성동구  1244
# 4       서울특별시 광진구  1472
# 5      서울특별시 동대문구  1833
# 6       서울특별시 중랑구  2050
# 7       서울특별시 성북구  2154
# 8       서울특별시 강북구  1854
# 9       서울특별시 도봉구  1776
# 10      서울특별시 노원구  2763
# 11      서울특별시 은평구  2309
# 12     서울특별시 서대문구  1516
# 13      서울특별시 마포구  1593
# 14      서울특별시 양천구  1898
# 15      서울특별시 강서구  2573
# 16      서울특별시 구로구  1731
# 17      서울특별시 금천구  1139
# 18     서울특별시 영등포구  1701
# 19      서울특별시 동작구  1677
# 20      서울특별시 관악구  2008
# 21      서울특별시 서초구  1396
# 22      서울특별시 강남구  1751
# 23      서울특별시 송파구  2127
# 24      서울특별시 강동구  1857
# 25       부산광역시 중구   357
# 26       부산광역시 서구  1039
# 27       부산광역시 동구   856
# 28      부산광역시 영도구  1104
# 29     부산광역시 부산진구  2353
# 30      부산광역시 동래구  1372
# 31       부산광역시 남구  1621
# 32       부산광역시 북구  1571
# 33     부산광역시 해운대구  2211
# 34      부산광역시 사하구  1931
# 35      부산광역시 금정구  1514
# 36      부산광역시 강서구   466
# 37      부산광역시 연제구  1107
# 38      부산광역시 수영구  1047
# 39      부산광역시 사상구  1405
# 40      부산광역시 기장군   866
# 41       대구광역시 중구   594
# 42       대구광역시 동구  2119
# 43       대구광역시 서구  1353
# 44       대구광역시 남구  1079
# 45       대구광역시 북구  2100
# 46      대구광역시 수성구  2104
# 47      대구광역시 달서구  2651
# 48      대구광역시 달성군  1081
# 49       인천광역시 중구   594
# 50       인천광역시 동구   459
# 51       인천광역시 남구  2309
# 52      인천광역시 연수구  1186
# 53      인천광역시 남동구  2223
# 54      인천광역시 부평구  2556
# 55      인천광역시 계양구  1364
# 56       인천광역시 서구  1902
# 57      인천광역시 강화군   689
# 58      인천광역시 옹진군   170
# 59       광주광역시 동구   732
# 60       광주광역시 서구  1546
# 61       광주광역시 남구  1263
# 62       광주광역시 북구  2322
# 63      광주광역시 광산구  1580
# 64       대전광역시 동구  1439
# 65       대전광역시 중구  1503
# 66       대전광역시 서구  1976
# 67      대전광역시 유성구  1085
# 68      대전광역시 대덕구   958
# 69       울산광역시 중구  1092
# 70       울산광역시 남구  1311
# 71       울산광역시 동구   698
# 72       울산광역시 북구   613
# 73      울산광역시 울주군  1201
# 74    세종특별자치시 세종시   979
# 75        경기도 수원시  4368
# 76        경기도 성남시  4105
# 77       경기도 의정부시  2023
# 78        경기도 안양시  2276
# 79        경기도 부천시  3531
# 80        경기도 광명시  1373
# 81        경기도 평택시  2208
# 82       경기도 동두천시   639
# 83        경기도 안산시  2586
# 84        경기도 고양시  4383
# 85        경기도 과천시   289
# 86        경기도 구리시   734
# 87       경기도 남양주시  2720
# 88        경기도 오산시   696
# 89        경기도 시흥시  1414
# 90        경기도 군포시  1007
# 91        경기도 의왕시   616
# 92        경기도 하남시   764
# 93        경기도 용인시  3525
# 94        경기도 파주시  2090
# 95        경기도 이천시  1050
# 96        경기도 안성시  1116
# 97        경기도 김포시  1407
# 98        경기도 화성시  1980
# 99        경기도 광주시  1282
# 100       경기도 양주시   992
# 101       경기도 포천시  1106
# 102       경기도 여주시   851
# 107       경기도 연천군   444
# 109       경기도 가평군   544
# 110       경기도 양평군   886
# 113       강원도 춘천시  1767
# 114       강원도 원주시  1836
# 115       강원도 강릉시  1553
# 116       강원도 동해시   681
# 117       강원도 태백시   374
# 118       강원도 속초시   587
# 119       강원도 삼척시   618
# 120       강원도 홍천군   641
# 121       강원도 횡성군   434
# 122       강원도 영월군   412
# 123       강원도 평창군   415
# 124       강원도 정선군   373
# 125       강원도 철원군   366
# 126       강원도 화천군   189
# 127       강원도 양구군   203
# 128       강원도 인제군   272
# 129       강원도 고성군   314
# 130       강원도 양양군   266
# 131      충청북도 충주시  1498
# 132      충청북도 제천시  1028
# 133      충청북도 청주시  4061
# 135      충청북도 보은군   458
# 136      충청북도 옥천군   567
# 137      충청북도 영동군   616
# 138      충청북도 진천군   511
# 139      충청북도 괴산군   479
# 140      충청북도 음성군   830
# 141      충청북도 단양군   344
# 142      충청북도 증평군   246
# 143      충청남도 천안시  2582
# 144      충청남도 공주시  1004
# 145      충청남도 보령시   957
